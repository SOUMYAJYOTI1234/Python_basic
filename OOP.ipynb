# %% [markdown]
# # 1)Object oriented programming is a way of writting code, where everything is organised around objects.

# %%
L = [1,2,3]

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s='hello'
s.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 s='hello'
# ----> 2 s.append()
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# note 'list' object, 'str' object 
# there's no upper() function in list, there's no append() function in string

# %%
# so, oop is a concept by which a developer can create his own datatype in python.

# %%
# Oop--> class,object,polymorphism,encapsulation,inheritence,abstraction

# %% [markdown]
# ## class

# %%
# class is a blueprint(basically, it is a set of rules)
# list,tuple,set,dictionary,string(basically, all the data types in python) are the built-in classes in python.
# A class is a set of rules, and object is an element of that class, like, car is a class, and marcedes is an object in that class.

# %%
L =[1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
# here [1,2,3] is a list and L is an object of that list.

# %%
# object is an instance of class
# Car--> wagnor  // wagnor=Car()
# Sports--> cricket  // cricket=Sports()
# Animals--> tiger  // tiger=Animals()
# syntax to create an object
# objectname = Classname()
# class name is given in pascal case, i.e if there are two words we club them with capitalising 
# first leter of each word. ex, HelloWorld.

# %% [markdown]
# Example ATM machine

# %%
class Atm:

    def __init__(self):
        self.pin=''
        self.balance = 0
        self.menu()
        
    def menu(self):
        user_input = input("""
        Hi how can I help you?
        1. Press 1 to create pin
        2. Press 2 to change pin
        3. Press 3 to check balance
        4. Press 4 to withdraw
        5. Anything else to exit
        """)
        if user_input == '1':
            # create pin
            self.create_pin()
        elif user_input == '2':
            # change pin
            self.change_pin()
        elif user_input == '3':
            # check balance
            self.check_balance()
        elif user_input == '4':
            # withdraw
            self.withdraw()
        else:
            exit()

    def create_pin(self):
        user_pin = input('enter your pin')
        self.pin= user_pin

        user_balance = int(input('enter your balance'))
        self.balance = user_balance

        print('pin created successfully')
        self.menu()
    def change_pin(self):
        old_pin=input('enter old pin: ')

        if old_pin == self.pin:
            # let him change the pin
            new_pin = input('enter new pin: ')
            self.pin = new_pin
            print('pin change successful')
            self.menu()
        else:
            print('please enter correct pin')
            self.menu()
    def check_balance(self):
        user_pin = input('enter the pin')
        if user_pin == self.pin:
            print('Your balance is:',self.balance)
            self.menu()
        else:
            print('please enter correct pin')
            self.menu()
    def withdraw(self):
        user_pin  = input('enter your pin:')
        if user_pin == self.pin:
            # allow to withdraw
            amount = int(input('please write the withdraw amount:'))
            if amount <= self.balance:
                print('Withdraw successful. current balance is:',self.balance - amount)
            else:
                print('Your balance is insufficient.')
        else:
            print('please write the correct pin')
            self.menu()
    
atm = Atm()
atm
# Out:
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#          1
# enter your pin 1234
# enter your balance 10000
# pin created successfully
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#          2
# enter old pin:  1234
# enter new pin:  123
# pin change successful
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#          3
# enter the pin 123
# Your balance is: 10000
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
# ...

# %%
# Method vs function
# Method is a function defined inside a class.
# Function is a block of code which performs a specific task.
# for example, L=[1,2,3],  L.append(4) --> here append is a method of list class.But len(L) --> here len is a function.

# %%
# class diagram:
# class name: Atm
# data/variables/attributes: pin,balance
# methods/functions: create_pin(), change_pin(), check_balance(), withdraw(), menu()

# %%
# Magic method aka dunder method (double underscore method): helps to make our own datatype in python.
# __init__() --> it is a constructor(one of the magic method), which is called automatically when an object of that class is created.
# it is used to initialize the attributes of the class.
# it helps to keep privavcy of data.

# %%
# self: in object oriented programming, inside a class no method can be called directly, it needs to be called by an object.
# so, self is used to represent the instance of the class, and it is used to access the attributes and methods of the class in python.
# it binds the attributes with the given arguments.
# And to be precise self is the object itself.

# %%
class Fraction:

  # parameterized constructor(because it takes arguments from the user)
  def __init__(self,x,y):
    self.num = x
    self.den = y
  # __str__ method is used to return a string representation of the object.
  def __str__(self):
    return '{}/{}'.format(self.num,self.den)
  # __add__ method is used to add two objects of the same class.
  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)
  # __sub__ method is used to subtract two objects of the same class.
  def __sub__(self,other):
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)
  # __mul__ method is used to multiply two objects of the same class.
  def __mul__(self,other):
    new_num = self.num*other.num
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)
  #v __truediv__ method is used to divide two objects of the same class.
  def __truediv__(self,other):
    new_num = self.num*other.den
    new_den = self.den*other.num

    return '{}/{}'.format(new_num,new_den)
  # convert_to_decimal method is used to convert the fraction to decimal.(Non magic method)
  def convert_to_decimal(self):
    return self.num/self.den

    
Fr1 = Fraction(3,8)
Fr2 = Fraction(1,2)

# %%
print(Fr1)
# Out:
# 3/8

# %%
print(Fr1 + Fr2)
print(Fr1 - Fr2)
print(Fr1 * Fr2)
print(Fr1 / Fr2)
# Out:
# 14/16
# -2/16
# 3/16
# 6/8

# %%
Fr1.convert_to_decimal()
# Out:
# 0.375

# %% [markdown]
# ##`Q-1:` Rectangle Class
# 1. Write a Rectangle class in Python language, allowing you to build a rectangle with length and width attributes.
#
# 2. Create a Perimeter() method to calculate the perimeter of the rectangle and a Area() method to calculate the area of ​​the rectangle.
#
# 3. Create a method display() that display the length, width, perimeter and area of an object created using an instantiation on rectangle class.

# %%
class Rectangle:
  def __init__(self,length,width):
    self.length = length
    self.width = width

  def perimiter(self):
    return 2*(self.length+self.width)

  def area(self):
    return self.length*self.width

  def display(self):
    print("The length of rectangle is:",self.length)
    print("The width of rectangle is:",self.width)
    print("The perimeter of rectangle is:",self.perimiter())
    print("The area of rectangle is:",self.area())

# %%
My_rectangle = Rectangle(3,4)

# %%
My_rectangle.display()
# Out:
# The length of rectangle is: 3
# The width of rectangle is: 4
# The perimeter of rectangle is: 14
# The area of rectangle is: 12

# %% [markdown]
# Q-3:Computation class
# Create a Computation class with a default constructor (without parameters) allowing to perform various calculations on integers numbers.
#
# Create a method called Factorial() which allows to calculate the factorial of an integer n. Integer n as parameter for this method
#
# Create a method called naturalSum() allowing to calculate the sum of the first n integers 1 + 2 + 3 + .. + n. Integer n as parameter for this method.
#
# Create a method called testPrime() in the Calculation class to test the primality of a given integer n, n is Prime or Not? Integer n as parameter for this method.
#
# Create a method called testPrims() allowing to test if two numbers are prime between them. Two integers are prime to one another if they have only 1 as their common divisor. Eg. 4 and 9 are prime to each other.
#
# Create a tableMult() method which creates and displays the multiplication table of a given integer. Then create an allTablesMult() method to display all the integer multiplication tables 1, 2, 3, ..., 9.
#
# Create a static listDiv() method that gets all the divisors of a given integer on new list called Ldiv. Create another listDivPrim() method that gets all the prime divisors of a given integer.

# %%
class Computation:
    def __init__(self):
        pass
    def Factorial(self,n):
        fact = 1
        for i in range(1,n+1):
            fact = fact*i
        return fact
    def naturalSum(self,n):
        result = 0
        for i in range(1,n+1):
            result+=i
        return result
    def testPrime(self,n):
        if n<=1:
            return False
        if n == 2:
            return True
        if n%2 == 0:
            return False
        for i in range(3,int(n**0.5)+1,2):
            if n%i == 0:
                return False
        return True
    def coPrime(self,a,b):
        smaller = min(a,b)
        for i in range(2,smaller+1):
            if a%i ==0 and b%i == 0:
                return False
        return True
    def tableMult(self,n):
        print(f"Multiplication Table of {n}:")
        for i in range(1,11):
            print(f"{n} x {i} = {n*i}")
    def allTableMult(self):
        for n in range(1,10):
            self.tableMult(n)
    @staticmethod
    def listDiv(n):
        LDiv = []
        for i in range(1,n+1):
            if n%i ==0:
                LDiv.append(i)
        return LDiv
    def listDivPrime(self,n):
        divisors = self.listDiv(n)
        prime_divisors =[]
        for d in divisors:
            if self.testPrime(d):
                prime_divisors.append(d)
        return prime_divisors

# %%
com = Computation()

# %%
com.Factorial(4)
# Out:
# 24

# %%
com.naturalSum(3)
# Out:
# 6

# %%
com.testPrime(7)
# Out:
# True

# %%
com.coPrime(2,9)
# Out:
# True

# %%
com.tableMult(13)
# Out:
# Multiplication Table of 13:
# 13 x 1 = 13
# 13 x 2 = 26
# 13 x 3 = 39
# 13 x 4 = 52
# 13 x 5 = 65
# 13 x 6 = 78
# 13 x 7 = 91
# 13 x 8 = 104
# 13 x 9 = 117
# 13 x 10 = 130

# %%
com.allTableMult()
# Out:
# Multiplication Table of 1:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# Multiplication Table of 2:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# Multiplication Table of 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# Multiplication Table of 4:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# Multiplication Table of 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# Multiplication Table of 6:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# Multiplication Table of 7:
# 7 x 1 = 7
# 7 x 2 = 14
# ...

# %%
com.listDiv(12)
# Out:
# [1, 2, 3, 4, 6, 12]

# %%
com.listDivPrime(12)
# Out:
# [2, 3]

# %% [markdown]
# Q-4: Build flashcard using class in Python.
# Build a flashcard using class in python. A flashcard is a card having information on both sides, which can be used as an aid in memoization. Flashcards usually have a question on one side and an answer on the other.
#
# Example 1:
#
# Approach:
#
# Create a class named FlashCard.
# Initialize dictionary fruits using init() method. Here you have to define fruit name as key and it's color as value. E.g., {"Banana": "yellow", "Strawberries": "pink"}
# Now randomly choose a pair from fruits by using random module and store the key in variable fruit and value in variable color.
# Now prompt the user to answer the color of the randomly chosen fruit.
# If correct print correct else print wrong.
# Output:
#
# welcome to fruit quiz
# What is the color of Strawberries
# pink
# Correct answer
# Enter 0, if you want to play again: 0
# What is the color of watermelon
# green
# Correct answer
# Enter 0, if you want to play again: 1

# %%
import random

class FlashCard:
    def __init__(self):
        # dictionary of fruits with their colors
        self.fruits = {
            "Banana": "yellow",
            "Strawberries": "pink",
            "Watermelon": "green",
            "Apple": "red",
            "Orange": "orange",
            "Grapes": "purple"
        }

    def quiz(self):
        print("Welcome to fruit quiz")
        
        while True:
            # randomly select a fruit-color pair
            fruit, color = random.choice(list(self.fruits.items()))
            
            # ask user
            print(f"What is the color of {fruit}?")
            user_answer = input().strip().lower()
            
            if user_answer == color.lower():
                print("Correct answer ✅")
            else:
                print(f"Wrong answer ❌, Correct color is {color}")
            
            # ask user to play again
            choice = input("Enter 0 if you want to play again, any other key to quit: ")
            if choice != "0":
                print("Thanks for playing! 👋")
                break


# create object and run quiz
game = FlashCard()
game.quiz()
# Out:
# Welcome to fruit quiz
# What is the color of Banana?
#  YEllow
# Correct answer ✅
# Enter 0 if you want to play again, any other key to quit:  0
# What is the color of Strawberries?
#  red
# Wrong answer ❌, Correct color is pink
# Enter 0 if you want to play again, any other key to quit:  9
# Thanks for playing! 👋

# %% [markdown]
# Write oop class to handle the following scenarios:
#
# a)User can create and view 2D coordinates
#
# b)User can find out the distance between 2 coordinates
#
# c)User can find the distance of a coordinate from the origin
#
# d)User can check if a point lies on a given line or not
#
# e)User can find the distance between a given 2D point and a given line.

# %%
import math
class Point:
    def __init__(self,x,y):
        self.x_cod = x
        self.y_cod = y
    def __str__(self):
        # return '({},{})'.format(self.x_cod,self.y_cod)
        return f"({self.x_cod},{self.y_cod})"
    def euclidean_distance(self,other):
        return (math.sqrt((self.x_cod-other.x_cod)**2 + (self.y_cod - other.y_cod)**2))
        # return ((self.x_cod-other.x_cod)**2 + (self.y_cod - other.y_cod)**2)**0.5
    def distance_from_origin(self):
        return self.euclidean_distance(Point(0,0))
        # return math.sqrt((self.x_cod**2 + self.y_cod**2))
class Line:
    def __init__(self,A,B,C):
        self.A = A
        self.B = B
        self.C = C
    def __str__(self):
        return f"{self.A}x + {self.B}y + {self.C} = 0"
    def point_on_line(line,point):
        if line.A * point.x_cod + line.B * point.y_cod + line.C == 0:
            return f"{point} lies on {line}"
        else:
            return f"{point} does't lie on {line}"
    def shortest_distance(line,point):
            return abs(line.A*point.x_cod +line.B*point.y_cod+line.C)/((line.A**2+line.B**2)**0.5)

# %%
p1 = Point(1,1)
p2 = Point(1,1)
print(p1)
p1.euclidean_distance(p2)
p2.distance_from_origin()
L1 =Line(1,1,0)
print(L1)
L1.point_on_line(p1)
L1.shortest_distance(p1)
# Out:
# (1,1)
# 1x + 1y + 0 = 0
# 1.414213562373095

# %% [markdown]
# ## Pass by reference

# %%
class Person:
    def __init__(self,name,gender):
        self.name=name
        self.gender=gender
def greet(someone):
    print('Hi my name is',someone.name,'and I am',someone.gender)
    p1 = Person('anikita','female')
    return p1
p=Person('ankita','female')
x=greet(p)
print(x.name)
print(x.gender)
# Out:
# Hi my name is ankita and I am female
# anikita
# female
