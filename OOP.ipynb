# %%
# Object oriented programming is a way of writting code, where everything is organised around objects.

# %%
L = [1,2,3]

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s='hello'
s.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 s='hello'
# ----> 2 s.append()
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# note 'list' object, 'str' object 
# there's no upper() function in list, there's no append() function in string

# %%
# so, oop is a concept by which a developer can create his own datatype in python.

# %%
# Oop--> class,object,polymorphism,encapsulation,inheritence,abstraction

# %% [markdown]
# ## class

# %%
# class is a blueprint(basically, it is a set of rules)
# list,tuple,set,dictionary,string(basically, all the data types in python) are the built-in classes in python.
# A class is a set of rules, and object is an element of that class, like, car is a class, and marcedes is an object in that class.

# %%
# object is an instance of class
# Car--> wagnor  // wagnor=Car()
# Sports--> cricket  // cricket=Sports()
# Animals--> tiger  // tiger=Animals()
# syntax to create an object
# objectname = Classname()
# class name is given in pascal case, i.e if there are two words we club them with capitalising 
# first leter of each word. ex, HelloWorld.

# %% [markdown]
# Example ATM machine

# %%
class Atm:

    def __init__(self):
        self.pin=''
        self.balance = 0
        self.menu()
        
    def menu(self):
        user_input = input("""
        Hi how can I help you?
        1. Press 1 to create pin
        2. Press 2 to change pin
        3. Press 3 to check balance
        4. Press 4 to withdraw
        5. Anything else to exit
        """)
        if user_input == '1':
            # create pin
            self.create_pin()
        elif user_input == '2':
            # change pin
            self.change_pin()
        elif user_input == '3':
            # check balance
            self.check_balance()
        elif user_input == '4':
            # withdraw
            self.withdraw()
        else:
            exit()

    def create_pin(self):
        user_pin = input('enter your pin')
        self.pin= user_pin

        user_balance = int(input('enter your balance'))
        self.balance = user_balance

        print('pin created successfully')
        self.menu()
    def change_pin(self):
        old_pin=input('enter old pin: ')

        if old_pin == self.pin:
            # let him change the pin
            new_pin = input('enter new pin: ')
            self.pin = new_pin
            print('pin change successful')
            self.menu()
        else:
            print('please enter correct pin')
            self.menu()
    def check_balance(self):
        user_pin = input('enter the pin')
        if user_pin == self.pin:
            print('Your balance is:',self.balance)
            self.menu()
        else:
            print('please enter correct pin')
            self.menu()
    def withdraw(self):
        user_pin  = input('enter your pin:')
        if user_pin == self.pin:
            # allow to withdraw
            amount = int(input('please write the withdraw amount:'))
            if amount <= self.balance:
                print('Withdraw successful. current balance is:',self.balance - amount)
            else:
                print('Your balance is insufficient.')
        else:
            print('please write the correct pin')
            self.menu()
    
atm = Atm()
atm
# Out:
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#          1
# enter your pin 1234
# enter your balance 10000
# pin created successfully
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#          2
# enter old pin:  1234
# enter new pin:  123
# pin change successful
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#          3
# enter the pin 123
# Your balance is: 10000
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
# ...

# %%
class Fraction:

  # parameterized constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __sub__(self,other):
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __mul__(self,other):
    new_num = self.num*other.num
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __truediv__(self,other):
    new_num = self.num*other.den
    new_den = self.den*other.num

    return '{}/{}'.format(new_num,new_den)

  def convert_to_decimal(self):
    return self.num/self.den

    
Fr1 = Fraction(3,8)
Fr2 = Fraction(1,2)

# %%
print(Fr1)
# Out:
# 3/8

# %%
print(Fr1 + Fr2)
print(Fr1 - Fr2)
print(Fr1 * Fr2)
print(Fr1 / Fr2)
# Out:
# 14/16
# -2/16
# 3/16
# 6/8

# %%
Fr1.convert_to_decimal()
# Out:
# 0.375

# %% [markdown]
# ##`Q-1:` Rectangle Class
# 1. Write a Rectangle class in Python language, allowing you to build a rectangle with length and width attributes.
#
# 2. Create a Perimeter() method to calculate the perimeter of the rectangle and a Area() method to calculate the area of ​​the rectangle.
#
# 3. Create a method display() that display the length, width, perimeter and area of an object created using an instantiation on rectangle class.

# %%
class Rectangle:
  def __init__(self,length,width):
    self.length = length
    self.width = width

  def perimiter(self):
    return 2*(self.length+self.width)

  def area(self):
    return self.length*self.width

  def display(self):
    print("The length of rectangle is:",self.length)
    print("The width of rectangle is:",self.width)
    print("The perimeter of rectangle is:",self.perimiter())
    print("The area of rectangle is:",self.area())

# %%
My_rectangle = Rectangle(3,4)

# %%
My_rectangle.display()
# Out:
# The length of rectangle is: 3
# The width of rectangle is: 4
# The perimeter of rectangle is: 14
# The area of rectangle is: 12
